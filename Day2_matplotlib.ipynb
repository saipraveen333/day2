# %% [markdown]
# <a href="https://colab.research.google.com/github/saipraveen333/day2/blob/main/Day2_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.plot(data['sepal_width'])

# %%
plt.plot(data['sepal_length'])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=sns.load_dataset('iris')
plt.plot(data['sepal_width'],color='green', label="sepal width", linestyle='dashed',marker='*')
plt.plot(data['sepal_length'],color='blue', label="sepal length",marker='*',linestyle='solid')
plt.xlabel('Indexes',fontsize=10,color='red')
plt.ylabel('Petal Counts',fontsize=10,color='red')
plt.title('Plots',fontsize=20,color='black')
plt.legend()

# %%
plt.bar(data['species'],data['petal_length'])
plt.bar(data['species'],data['petal_width'])
# Out:
# <BarContainer object of 150 artists>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
import numpy as np

# %%
data=sb.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure(figsize=(10,5))
plt.grid()
plt.plot(data['sepal_length'],color='green',linestyle='--',marker='*',label='sepal length',linewidth=1)
plt.plot(data['sepal_width'],color='blue',linestyle='solid',marker='*',label='sepal width',linewidth=1)
plt.xlabel('Indices',fontsize='15',color='brown')
plt.ylabel('Sepal Dimensions',fontsize='15',color='brown')
plt.title('Iris Plots',fontsize='30',color='grey')
plt.legend()

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.bar(tips['day'],tips['total_bill'])
# Out:
# <BarContainer object of 244 artists>

# %%
plt.barh(tips['day'],tips['total_bill'])
# Out:
# <BarContainer object of 244 artists>

# %%
tips=sns.load_dataset('tips')
plt.hist(tips['total_bill'],edgecolor='red')
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %%
day=tips.groupby('day')['total_bill'].sum().reset_index()
day
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
plt.figure(figsize=(50,5))
x=day['day']
y=day['total_bill']
plt.pie(y,labels=x,explode =[0,0,0,0.1],autopct='%1.2f%%',colors=['red','pink','green','violet'],startangle=90,
        wedgeprops = {'edgecolor' : 'black'},shadow='true')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
sns.boxplot(x = 'day', y = 'tip', data = tips, hue = 'sex')
